# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from bs4 import BeautifulSoup as BS
import requests
from time import sleep
from selenium import webdriver
import unicodedata

# %% [markdown]
# # Creating the urls

# %%
base_url = 'https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page='
page_url_num = '1'
add_url = '&mode=liste'
# https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&mode=liste
# https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page=2&mode=liste

# %%
url1 = base_url + page_url_num + add_url
print(url1)
# Out:
# https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page=1&mode=liste

# %% [markdown]
# # Extracting the pages information with BeautifulSoup

# %%
options = webdriver.EdgeOptions()
# options.headless = True   # just set it to the headless mode

browser1 = webdriver.Edge(options=options)
browser1.get(url1)

page1 = browser1.page_source

sleep(5)

soup1 = BS(page1, 'html.parser')
soup1.prettify()
# Out:
# '<html lang="fr">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Bien’ici\n  </title>\n  <script async="" crossorigin="anonymous" id="b151ba30-4cbc-11ee-85fd-1145ffddfee4" src="https://core.carte.bienici.com/benchmark.js" type="text/javascript">\n  </script>\n  <script async="" charset="utf-8" id="spcloader" src="https://sdk.privacy-center.org/7d581840-66fa-4f8f-b890-b612c6c34d07/loader.js?target=www.bienici.com" type="text/javascript">\n  </script>\n  <script async="" id="b0f2aa40-4cbc-11ee-85fd-1145ffddfee4" src="/gtm.js?id=GTM-N8CZ9B" type="text/javascript">\n  </script>\n  <script>\n   !function(){function i(){delete window.navigationStartRefined,document.removeEventListener("visibilitychange",i)}"visible"===document.visibilityState&&(document.addEventListener("visibilitychange",i),window.navigationStartRefined=Date.now())}();\n  </script>\n  <link data-default-href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" rel="icon" type="image/png"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="shortcut icon"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="icon" type="image/x-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-startup-image"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/b92a55e91e116da95d789d60a6e265027ba8d07c/fonts/Roboto-Condensed.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/8c65d3b85a37264f4378e61cbf37ebad1adc02fb/fonts/Roboto-Condensed-Bold.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/044f8ee57aac7b5023986615a23d22de3a3c3df1/fonts/Material-Design-Iconic-Font.woff" rel="preload" type="font/woff"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/7f2f3c55c2de192387c351b995115f6b79e09173/fonts/fontawesome-webfont.woff" rel="preload" type="font/woff"/>\n  <link href="https://account.bienici.com" rel="preconnect"/>\n  <link href="https://core.carte.bienici.com" rel="preconnect"/>\n  <link href="https://storage.gra.cloud.ovh.net/v1/AUTH_e0b83750570d4ff1986fe199b41300e4/kimono/" rel="preconnect"/>\n  <link href="https://file.bienici.com" rel="preconnect"/>\n  <link href="https://res.bienici.com" rel="preconnect"/>\n  <link href="https://watcher.bienici.com" rel="preconnect"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>\n  <meta content="Bien’ici" name="apple-mobile-web-app-title"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <meta app-argument="https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&amp;prix-max=1000&amp;page=1&amp;mode=liste" content="app-id=1181371766" name="apple-itunes-app"/>\n  <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="1650758831830906" property="fb:app_id"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Bien’ici" property="og:title"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Bien’ ...

# %%
base_url = 'https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page='
page_url_num = '2'
add_url = '&mode=liste'
url2 = base_url + page_url_num + add_url
print(url2)
# Out:
# https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page=2&mode=liste

# %%
base_url = 'https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page='
page_url_num = '3'
add_url = '&mode=liste'
url3 = base_url + page_url_num + add_url
print(url3)
# Out:
# https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page=3&mode=liste

# %%
base_url = 'https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page='
page_url_num = '4'
add_url = '&mode=liste'
url4 = base_url + page_url_num + add_url
print(url4)
# Out:
# https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&prix-max=1000&page=4&mode=liste

# %%
options = webdriver.EdgeOptions()
# options.headless = True   # just set it to the headless mode

browser2 = webdriver.Edge(options=options)
browser2.get(url2)

page2 = browser2.page_source

sleep(40)

soup2 = BS(page2, 'html.parser')
soup2.prettify()
# Out:
# '<html lang="fr">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Page 2 - Bien’ici\n  </title>\n  <script async="" crossorigin="anonymous" id="1cb7f860-4cbe-11ee-8dda-afb84bd34340" src="https://core.carte.bienici.com/benchmark.js" type="text/javascript">\n  </script>\n  <script async="" charset="utf-8" id="spcloader" src="https://sdk.privacy-center.org/7d581840-66fa-4f8f-b890-b612c6c34d07/loader.js?target=www.bienici.com" type="text/javascript">\n  </script>\n  <script async="" id="1c71c7a0-4cbe-11ee-8dda-afb84bd34340" src="/gtm.js?id=GTM-N8CZ9B" type="text/javascript">\n  </script>\n  <script>\n   !function(){function i(){delete window.navigationStartRefined,document.removeEventListener("visibilitychange",i)}"visible"===document.visibilityState&&(document.addEventListener("visibilitychange",i),window.navigationStartRefined=Date.now())}();\n  </script>\n  <link data-default-href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" rel="icon" type="image/png"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="shortcut icon"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="icon" type="image/x-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-startup-image"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/b92a55e91e116da95d789d60a6e265027ba8d07c/fonts/Roboto-Condensed.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/8c65d3b85a37264f4378e61cbf37ebad1adc02fb/fonts/Roboto-Condensed-Bold.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/044f8ee57aac7b5023986615a23d22de3a3c3df1/fonts/Material-Design-Iconic-Font.woff" rel="preload" type="font/woff"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/7f2f3c55c2de192387c351b995115f6b79e09173/fonts/fontawesome-webfont.woff" rel="preload" type="font/woff"/>\n  <link href="https://account.bienici.com" rel="preconnect"/>\n  <link href="https://core.carte.bienici.com" rel="preconnect"/>\n  <link href="https://storage.gra.cloud.ovh.net/v1/AUTH_e0b83750570d4ff1986fe199b41300e4/kimono/" rel="preconnect"/>\n  <link href="https://file.bienici.com" rel="preconnect"/>\n  <link href="https://res.bienici.com" rel="preconnect"/>\n  <link href="https://watcher.bienici.com" rel="preconnect"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>\n  <meta content="Bien’ici" name="apple-mobile-web-app-title"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <meta app-argument="https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&amp;prix-max=1000&amp;page=2&amp;mode=liste" content="app-id=1181371766" name="apple-itunes-app"/>\n  <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="1650758831830906" property="fb:app_id"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Page 2 - Bien’ici" property="og:title"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa ...

# %%
browser3 = webdriver.Edge(options=options)
browser3.get(url3)

page3 = browser3.page_source

sleep(10)

soup3 = BS(page3, 'html.parser')
soup3.prettify()
# Out:
# '<html lang="fr">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Page 3 - Bien’ici\n  </title>\n  <script async="" crossorigin="anonymous" id="7a75ecf0-4cbe-11ee-8401-5d2642faea11" src="https://core.carte.bienici.com/benchmark.js" type="text/javascript">\n  </script>\n  <script async="" charset="utf-8" id="spcloader" src="https://sdk.privacy-center.org/7d581840-66fa-4f8f-b890-b612c6c34d07/loader.js?target=www.bienici.com" type="text/javascript">\n  </script>\n  <script async="" id="7832b3b0-4cbe-11ee-8401-5d2642faea11" src="/gtm.js?id=GTM-N8CZ9B" type="text/javascript">\n  </script>\n  <script>\n   !function(){function i(){delete window.navigationStartRefined,document.removeEventListener("visibilitychange",i)}"visible"===document.visibilityState&&(document.addEventListener("visibilitychange",i),window.navigationStartRefined=Date.now())}();\n  </script>\n  <link data-default-href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" rel="icon" type="image/png"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="shortcut icon"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="icon" type="image/x-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-startup-image"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/b92a55e91e116da95d789d60a6e265027ba8d07c/fonts/Roboto-Condensed.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/8c65d3b85a37264f4378e61cbf37ebad1adc02fb/fonts/Roboto-Condensed-Bold.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/044f8ee57aac7b5023986615a23d22de3a3c3df1/fonts/Material-Design-Iconic-Font.woff" rel="preload" type="font/woff"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/7f2f3c55c2de192387c351b995115f6b79e09173/fonts/fontawesome-webfont.woff" rel="preload" type="font/woff"/>\n  <link href="https://account.bienici.com" rel="preconnect"/>\n  <link href="https://core.carte.bienici.com" rel="preconnect"/>\n  <link href="https://storage.gra.cloud.ovh.net/v1/AUTH_e0b83750570d4ff1986fe199b41300e4/kimono/" rel="preconnect"/>\n  <link href="https://file.bienici.com" rel="preconnect"/>\n  <link href="https://res.bienici.com" rel="preconnect"/>\n  <link href="https://watcher.bienici.com" rel="preconnect"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>\n  <meta content="Bien’ici" name="apple-mobile-web-app-title"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <meta app-argument="https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&amp;prix-max=1000&amp;page=3&amp;mode=liste" content="app-id=1181371766" name="apple-itunes-app"/>\n  <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="1650758831830906" property="fb:app_id"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Page 3 - Bien’ici" property="og:title"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa ...

# %%
browser4 = webdriver.Edge(options=options)
browser4.get(url4)

page4 = browser4.page_source

sleep(19)

soup4 = BS(page4, 'html.parser')
soup4.prettify()
# Out:
# '<html lang="fr">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Page 4 - Bien’ici\n  </title>\n  <script async="" crossorigin="anonymous" id="cfb31a70-4cbf-11ee-be46-830926c425bc" src="https://core.carte.bienici.com/benchmark.js" type="text/javascript">\n  </script>\n  <script async="" charset="utf-8" id="spcloader" src="https://sdk.privacy-center.org/7d581840-66fa-4f8f-b890-b612c6c34d07/loader.js?target=www.bienici.com" type="text/javascript">\n  </script>\n  <script async="" id="cf51c090-4cbf-11ee-be46-830926c425bc" src="/gtm.js?id=GTM-N8CZ9B" type="text/javascript">\n  </script>\n  <script>\n   !function(){function i(){delete window.navigationStartRefined,document.removeEventListener("visibilitychange",i)}"visible"===document.visibilityState&&(document.addEventListener("visibilitychange",i),window.navigationStartRefined=Date.now())}();\n  </script>\n  <link data-default-href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" href="https://res.bienici.com/cacheForever/386ac59bace95174ef689c38c7808498d9462e08/images/favicon/bienici.png" rel="icon" type="image/png"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="shortcut icon"/>\n  <link href="https://res.bienici.com/cacheForever/ca36cf95984b75fd4620b9dd4ca0b24bc82a2116/favicon.ico" rel="icon" type="image/x-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-icon"/>\n  <link href="https://res.bienici.com/cacheForever/f19bfd7564e5f67ef0bbaf56b4b42246af75999c/images/favicon/touch-icon.png" rel="apple-touch-startup-image"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/b92a55e91e116da95d789d60a6e265027ba8d07c/fonts/Roboto-Condensed.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/8c65d3b85a37264f4378e61cbf37ebad1adc02fb/fonts/Roboto-Condensed-Bold.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/044f8ee57aac7b5023986615a23d22de3a3c3df1/fonts/Material-Design-Iconic-Font.woff" rel="preload" type="font/woff"/>\n  <link as="font" crossorigin="anonymous" href="https://res.bienici.com/cacheForever/7f2f3c55c2de192387c351b995115f6b79e09173/fonts/fontawesome-webfont.woff" rel="preload" type="font/woff"/>\n  <link href="https://account.bienici.com" rel="preconnect"/>\n  <link href="https://core.carte.bienici.com" rel="preconnect"/>\n  <link href="https://storage.gra.cloud.ovh.net/v1/AUTH_e0b83750570d4ff1986fe199b41300e4/kimono/" rel="preconnect"/>\n  <link href="https://file.bienici.com" rel="preconnect"/>\n  <link href="https://res.bienici.com" rel="preconnect"/>\n  <link href="https://watcher.bienici.com" rel="preconnect"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>\n  <meta content="Bien’ici" name="apple-mobile-web-app-title"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <meta app-argument="https://www.bienici.com/recherche/location/paris-75000/appartement?prix-min=300&amp;prix-max=1000&amp;page=4&amp;mode=liste" content="app-id=1181371766" name="apple-itunes-app"/>\n  <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="1650758831830906" property="fb:app_id"/>\n  <meta content="website" property="og:type"/>\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa0000\xa0€) - Page 4 - Bien’ici" property="og:title"/>\n  <meta content="Location appartement Paris (75000) (300\xa0à\xa01\xa ...

# %% [markdown]
# # Housing and Surface

# %% [markdown]
# ##### Extracting the type of housing and the surface for all the pages on the BienIci website

# %%
v1 = soup1.find_all('span', attrs={"class":"ad-overview-details__ad-title"})
v1 = [unicodedata.normalize("NFKC", x.get_text(strip=True)) for x in v1]
v1
# Out:
# ['Appartement meublé 1 pièce 11 m2',
#  'Studio 28 m2',
#  'Appartement 1 pièce 25 m2',
#  'Appartement meublé 5 pièces 13 m2',
#  'Appartement 1 pièce 9 m2',
#  'Appartement meublé 1 pièce 16 m2',
#  'Appartement meublé 1 pièce 26 m2',
#  'Appartement meublé 1 pièce 44 m2',
#  'Appartement meublé 2 pièces 30 m2',
#  'Appartement 1 pièce 16 m2',
#  'Appartement 2 pièces 30 m2',
#  'Appartement meublé 1 pièce 16 m2',
#  'Appartement 1 pièce 30 m2',
#  'Appartement meublé 1 pièce 17 m2',
#  'Appartement meublé 1 pièce 16 m2',
#  'Appartement meublé 1 pièce 21 m2',
#  'Appartement meublé 2 pièces 17 m2',
#  'Studio meublé 15 m2',
#  'Appartement 1 pièce 26 m2',
#  'Appartement meublé 2 pièces 20 m2',
#  'Studio 24 m2',
#  'Studio 9 m2',
#  'Appartement 1 pièce 22 m2',
#  'Studio meublé 15 m2',
#  'Studio 30 m2',
#  'Appartement 1 pièce 16 m2']

# %%
v2 = soup2.find_all('span', attrs={"class":"ad-overview-details__ad-title"})
v2 = [unicodedata.normalize("NFKC", x.get_text(strip=True)) for x in v2]
v2
# Out:
# ['Studio 28 m2',
#  'Appartement meublé 1 pièce 11 m2',
#  'Studio meublé 14 m2',
#  'Studio meublé 14 m2',
#  'Appartement meublé 2 pièces 18 m2',
#  'Studio 17 m2',
#  'Appartement 2 pièces 35 m2',
#  'Appartement meublé 1 pièce 15 m2',
#  'Appartement meublé 1 pièce 31 m2',
#  'Appartement 2 pièces 36 m2',
#  'Appartement meublé 1 pièce 11 m2',
#  'Appartement meublé 1 pièce 29 m2',
#  'Appartement 1 pièce 20 m2',
#  'Appartement meublé 2 pièces 17 m2',
#  'Appartement 1 pièce 25 m2',
#  'Studio meublé 18 m2',
#  'Appartement 2 pièces 33 m2',
#  'Appartement meublé 1 pièce 16 m2',
#  'Studio meublé 14 m2',
#  'Appartement meublé 2 pièces 29 m2',
#  'Studio meublé 20 m2',
#  'Studio 27 m2',
#  'Studio meublé 17 m2',
#  'Studio meublé 20 m2',
#  'Appartement 2 pièces 40 m2',
#  'Appartement 2 pièces 39 m2']

# %%
v3 = soup3.find_all('span', attrs={"class":"ad-overview-details__ad-title"})
v3 = [unicodedata.normalize("NFKC", x.get_text(strip=True)) for x in v3]
v3
# Out:
# ['Appartement 2 pièces 30 m2',
#  'Studio 28 m2',
#  'Appartement meublé 2 pièces 17 m2',
#  'Appartement 1 pièce 17 m2',
#  'Appartement meublé 2 pièces 19 m2',
#  'Studio meublé 14 m2',
#  'Appartement meublé 3 pièces 32 m2',
#  'Appartement meublé 2 pièces 19 m2',
#  'Studio 29 m2',
#  'Studio meublé 17 m2',
#  'Studio 12 m2',
#  'Studio meublé 17 m2',
#  'Appartement 2 pièces 32 m2',
#  'Appartement 1 pièce 16 m2',
#  'Studio meublé 9 m2',
#  'Appartement 1 pièce 28 m2',
#  'Appartement 1 pièce 34 m2',
#  'Studio meublé 15 m2',
#  'Appartement 1 pièce 24 m2',
#  'Appartement 1 pièce 17 m2',
#  'Appartement 2 pièces 30 m2',
#  'Appartement meublé 2 pièces 21 m2',
#  'Studio 28 m2',
#  'Studio 22 m2',
#  'Appartement meublé 1 pièce 12 m2',
#  'Studio 14 m2']

# %%
v4 = soup4.find_all('span', attrs={"class":"ad-overview-details__ad-title"})
v4 = [unicodedata.normalize("NFKC", x.get_text(strip=True)) for x in v4]
v4
# Out:
# ['Appartement 2 pièces 30 m2',
#  'Studio 28 m2',
#  'Studio 22 m2',
#  'Studio meublé 13 m2',
#  'Appartement 1 pièce 20 m2',
#  'Studio 12 m2',
#  'Appartement 1 pièce 18 m2',
#  'Appartement meublé 1 pièce 17 m2',
#  'Appartement 1 pièce 11 m2',
#  'Studio 10 m2',
#  'Studio 14 m2',
#  'Appartement 1 pièce 27 m2',
#  'Appartement 1 pièce 28 m2',
#  'Appartement 1 pièce 15 m2',
#  'Appartement 1 pièce 15 m2',
#  'Studio 20 m2',
#  'Studio 9 m2',
#  'Studio 22 m2',
#  'Studio 20 m2']

# %% [markdown]
# ##### Storing the information on a list

# %%
housing = []
housing.extend(v1)
housing.extend(v2)
housing.extend(v3)
housing.extend(v4)
len(housing)
# Out:
# 97

# %% [markdown]
# ###### Separating the surface of the apartment from the housing type

# %%
surface = []

for i in range(0,len(housing)):
    var = [int(j) for j in housing[i].split() if j.isdigit()]
    if int(var[-1]) >= 9:
        var = var[-1]
        surface.append(int(var))
    # print(i, var, surface[i])
    
len(surface)
# Out:
# 97

# %%
var3 = []
for i in range(0,len(housing)):
    var2 = [j for j in housing[i].split() if j.isdigit()==False]# and int(v2[i].split()[-2]) >= 9]
    #var2 = [var2[i].replace(['pièce','pièces','m2'],'').strip() for x in var2[i]]
    var3.append(var2)
    # print(i, v3)#, surface[i])
    
len(var3)
# Out:
# 97

# %% [markdown]
# ###### Using a DataFrame to eliminate undesired names

# %%
columns = ['name1','name2','unused1','unused2']
df1 = pd.DataFrame(var3, columns = columns)
df1
# Out:
#           name1   name2 unused1 unused2
# 0   Appartement  meublé   pièce      m2
# 1        Studio      m2    None    None
# 2   Appartement   pièce      m2    None
# 3   Appartement  meublé  pièces      m2
# 4   Appartement   pièce      m2    None
# ..          ...     ...     ...     ...
# 92  Appartement   pièce      m2    None
# 93       Studio      m2    None    None
# 94       Studio      m2    None    None
# 95       Studio      m2    None    None
# 96       Studio      m2    None    None
#
# [97 rows x 4 columns]

# %%
df2 = df1
df2 = df2.drop(['unused1','unused2'], axis=1)
df2
# Out:
#           name1   name2
# 0   Appartement  meublé
# 1        Studio      m2
# 2   Appartement   pièce
# 3   Appartement  meublé
# 4   Appartement   pièce
# ..          ...     ...
# 92  Appartement   pièce
# 93       Studio      m2
# 94       Studio      m2
# 95       Studio      m2
# 96       Studio      m2
#
# [97 rows x 2 columns]

# %% [markdown]
# ###### Replacing the values in the column 'name2' for 'None'

# %%
var4 = list(df2['name2'])

# %%
var5 = [] # var for eliminating 'pièce' and 'm2'
#v5 = v5.extend([x.replace('pièce','').split() for x in v4])
#v5

var6 = [] # var5 after replacing 'pièce' and 'm2' for 'None'


for i in range(0,len(var4)):
    var5 = var4[i].replace('pièce','None').replace('m2','None').split()
    var6.extend(var5)
    # print(var5,var6)

# %% [markdown]
# ###### Manipulating the names

# %%
var7 = list(df2['name1']) # the first housing name
name = [] # the result

for i in range(0,len(var7)):
    if var6[i] != 'None':
        var = var7[i] + ' ' + var6[i]
    else:
        var = var7[i]
    name.append(var)
    # print(i, name)

# %%
len(name)
# Out:
# 97

# %% [markdown]
# ###### Storing the data into a temporary DataFrame

# %%
t1 = pd.DataFrame([name,surface], index=['Housing','Surface'])
t1 = t1.transpose()
t1
# Out:
#                Housing Surface
# 0   Appartement meublé      11
# 1               Studio      28
# 2          Appartement      25
# 3   Appartement meublé      13
# 4          Appartement       9
# ..                 ...     ...
# 92         Appartement      15
# 93              Studio      20
# 94              Studio       9
# 95              Studio      22
# 96              Studio      20
#
# [97 rows x 2 columns]

# %% [markdown]
# # Price

# %% [markdown]
# ##### Extracting the prices of all the advertisements

# %%
price1 = soup1.find_all('span', {"class":"ad-price__the-price"})
price1 = [unicodedata.normalize("NFKC", x.get_text()) for x in price1]
price1 = [x.strip(' €') for x in price1]

# %%
price2 = soup2.find_all('span', {"class":"ad-price__the-price"})
price2 = [unicodedata.normalize("NFKC", x.get_text()) for x in price2]
price2 = [x.strip(' €') for x in price2]

# %%
price3 = soup3.find_all('span', {"class":"ad-price__the-price"})
price3 = [unicodedata.normalize("NFKC", x.get_text()) for x in price3]
price3 = [x.strip(' €') for x in price3]

# %%
price4 = soup4.find_all('span', {"class":"ad-price__the-price"})
price4 = [unicodedata.normalize("NFKC", x.get_text()) for x in price4]
price4 = [x.strip(' €') for x in price4]

# %%
len(price1)+len(price2)+len(price3)+len(price4)
# Out:
# 97

# %% [markdown]
# ##### Storing everything under the same list

# %%
price = []
price.extend(price1)
price.extend(price2)
price.extend(price3)
price.extend(price4)
len(price)
# Out:
# 97

# %% [markdown]
# ##### Adding it to the temp. dataframe

# %%
t1['Price'] = price
t1
# Out:
#                Housing Surface Price
# 0   Appartement meublé      11   750
# 1               Studio      28   950
# 2          Appartement      25   876
# 3   Appartement meublé      13   800
# 4          Appartement       9   340
# ..                 ...     ...   ...
# 92         Appartement      15   840
# 93              Studio      20   870
# 94              Studio       9   530
# 95              Studio      22   900
# 96              Studio      20   850
#
# [97 rows x 3 columns]

# %% [markdown]
# # Address

# %% [markdown]
# ##### Extracting the address of all the advertisements

# %%
address1 = soup1.find_all('span', attrs={"class":"ad-overview-details__address-title"})
address1 = [unicodedata.normalize("NFKC", x.get_text()) for x in address1]
address1
# Out:
# ['75116 Paris 16e (Dauphine)',
#  '75015 Paris 15e (Alleray - Procession)',
#  "75010 Paris 10e (Château d'Eau - Lancry)",
#  '75017 Paris 17e (Champerret - Berthier)',
#  '75015 Paris 15e (Dupleix - Motte Picquet)',
#  '75020 Paris 20e (Plaine - Lagny)',
#  '75019 Paris 19e (Secrétan - Jaurès)',
#  '75019 Paris 19e (La Villette - Porte de Pantin)',
#  '75018 Paris 18e (La Chapelle - Marx Dormoy)',
#  '75002 Paris 2e (Sentier)',
#  '75018 Paris 18e (Barbès - Château Rouge)',
#  "75014 Paris 14e (Jean Moulin - Porte d'Orléans)",
#  '75016 Paris 16e (Porte de Saint-Cloud - Auteuil-Sud)',
#  '75007 Paris 7e (Champ de Mars)',
#  '75116 Paris 16e (Muette-Nord - Trocadéro)',
#  '75004 Paris 4e (Arsenal)',
#  '75018 Paris 18e (Jules Joffrin)',
#  '75018 Paris 18e (Grandes Carrières - Clichy)',
#  '75005 Paris 5e (Sorbonne - Quartier Latin)',
#  '75017 Paris 17e (Epinettes - Bessières)',
#  '75015 Paris 15e (Dupleix - Motte Picquet)',
#  '75019 Paris 19e (Jourdain - Pyrénées)',
#  '75015 Paris 15e (Pasteur - Montparnasse)',
#  '75018 Paris 18e (Jules Joffrin)',
#  '75018 Paris 18e (La Chapelle - Marx Dormoy)',
#  '75116 Paris 16e (Muette-Nord - Trocadéro)']

# %%
address2 = soup2.find_all('span', attrs={"class":"ad-overview-details__address-title"})
address2 = [unicodedata.normalize("NFKC", x.get_text()) for x in address2]

# %%
address3 = soup3.find_all('span', attrs={"class":"ad-overview-details__address-title"})
address3 = [unicodedata.normalize("NFKC", x.get_text()) for x in address3]

# %%
address4 = soup4.find_all('span', attrs={"class":"ad-overview-details__address-title"})
address4 = [unicodedata.normalize("NFKC", x.get_text()) for x in address4]

# %% [markdown]
# ##### Storing everything under the same variable

# %%
address = []
address.extend(address1)
address.extend(address2)
address.extend(address3)
address.extend(address4)
len(address)
# Out:
# 97

# %% [markdown]
#  ##### Separating the complement from the address

# %%
test1 = [x.split('(') for x in address]
test1
# Out:
# [['75116 Paris 16e ', 'Dauphine)'],
#  ['75015 Paris 15e ', 'Alleray - Procession)'],
#  ['75010 Paris 10e ', "Château d'Eau - Lancry)"],
#  ['75017 Paris 17e ', 'Champerret - Berthier)'],
#  ['75015 Paris 15e ', 'Dupleix - Motte Picquet)'],
#  ['75020 Paris 20e ', 'Plaine - Lagny)'],
#  ['75019 Paris 19e ', 'Secrétan - Jaurès)'],
#  ['75019 Paris 19e ', 'La Villette - Porte de Pantin)'],
#  ['75018 Paris 18e ', 'La Chapelle - Marx Dormoy)'],
#  ['75002 Paris 2e ', 'Sentier)'],
#  ['75018 Paris 18e ', 'Barbès - Château Rouge)'],
#  ['75014 Paris 14e ', "Jean Moulin - Porte d'Orléans)"],
#  ['75016 Paris 16e ', 'Porte de Saint-Cloud - Auteuil-Sud)'],
#  ['75007 Paris 7e ', 'Champ de Mars)'],
#  ['75116 Paris 16e ', 'Muette-Nord - Trocadéro)'],
#  ['75004 Paris 4e ', 'Arsenal)'],
#  ['75018 Paris 18e ', 'Jules Joffrin)'],
#  ['75018 Paris 18e ', 'Grandes Carrières - Clichy)'],
#  ['75005 Paris 5e ', 'Sorbonne - Quartier Latin)'],
#  ['75017 Paris 17e ', 'Epinettes - Bessières)'],
#  ['75015 Paris 15e ', 'Dupleix - Motte Picquet)'],
#  ['75019 Paris 19e ', 'Jourdain - Pyrénées)'],
#  ['75015 Paris 15e ', 'Pasteur - Montparnasse)'],
#  ['75018 Paris 18e ', 'Jules Joffrin)'],
#  ['75018 Paris 18e ', 'La Chapelle - Marx Dormoy)'],
#  ['75116 Paris 16e ', 'Muette-Nord - Trocadéro)'],
#  ['75015 Paris 15e ', 'Alleray - Procession)'],
#  ['75116 Paris 16e ', 'Dauphine)'],
#  ['75017 Paris 17e ', 'Epinettes - Bessières)'],
#  ['75020 Paris 20e ', 'Gambetta)'],
#  ['75019 Paris 19e ', 'Porte des Lilas)'],
#  ['75014 Paris 14e ', 'Pernety)'],
#  ['75018 Paris 18e ', 'Grandes Carrières - Clichy)'],
#  ['75007 Paris 7e ', 'Invalides)'],
#  ['75018 Paris 18e ', 'Jules Joffrin)'],
#  ['75017 Paris 17e ', 'La Fourche - Guy Moquet)'],
#  ['75116 Paris 16e ', 'Dauphine)'],
#  ['75020 Paris 20e ', 'Belleville)'],
#  ['75020 Paris 20e ', 'Gambetta)'],
#  ['75019 Paris 19e ', 'Jourdain - Pyrénées)'],
#  ['75013 Paris 13e ', 'Croulebarbe)'],
#  ['75015 Paris 15e ', 'Pasteur - Montparnasse)'],
#  ['75015 Paris 15e ', 'Vaugirard - Parc des Expositions)'],
#  ['75018 Paris 18e ', 'Grandes Carrières - Clichy)'],
#  ['75011 Paris 11e ', 'République - Saint-Ambroise)'],
#  ['75010 Paris 10e ', 'Saint-Vincent de Paul - Lariboisière)'],
#  ['75011 Paris 11e ', 'Belleville - Saint-Maur)'],
#  ['75019 Paris 19e ', 'Secrétan - Jaurès)'],
#  ['75020 Paris 20e ', 'Télégraphe - Pelleport - Saint-Fargeau)'],
#  ['75017 Paris 17e ', 'Epinettes - Bessières)'],
#  ['75019 Paris 19e ', 'Flandre - Aubervilliers)'],
#  ['75009 Paris 9e ', 'Porte Saint-Martin - Paradis)'],
#  ['75017 Paris 17e ', 'Ternes - Maillot)'],
#  ['75015 Paris 15e ', 'Alleray - Procession)'],
#  ['75018 Paris 18e ', 'Simplon - Poissonniers)'],
#  ['75014 Paris 14e ', 'Mouton - Duvernet)'],
#  ['75020 Paris 20e ', 'Télégraphe - Pelleport - Saint-Fargeau)'],
#  ['75018 Paris 18e ', 'La Chapelle - Marx Dormoy)'],
#  ['75012 Paris 12e ', 'Jardin de Reuilly)'],
#  ['75018 Paris 18e ', 'La Chapelle - Marx Dormoy)'],
#  ['75010 Paris 10e ', 'Louis Blanc - Aqueduc)'],
#  ['75015 Paris 15e ', 'Emeriau - Zola)'],
#  ['75018 Paris 18e ', 'Grandes Carrières - Clichy)'],
#  ['75014 Paris 14e ', 'Montsouris - Dareau)'],
#  ['75010 Paris 10e ', 'Saint-Vincent de Paul - Lariboisière)'],
#  ['75015 Paris 15e ', 'Cambronne - Garibaldi)'],
#  ['75019 Paris 19e ', 'Flandre - Aubervilliers)'],
#  ['75019 Paris 19e ', 'Danube)'],
#  ['75012 Paris 12e ', 'Jardin de Reuilly)'],
#  ['75020 Paris 20e ', 'Plaine - Lagny)'],
#  ['75015 Paris 15e ', 'Vaugirard - Parc des Expositions)'],
#  ['75012 Paris 12e ', 'Vallée de Fecamp)'],
#  ['75017 Paris 17e ', 'Ternes - Maillot)'],
#  ['75018 Paris 18e ', 'La Chapelle - Marx Dormoy)'],
#  ['75015 Paris 15e ', 'Alleray - Procession)'],
#  ['75015 Paris 15e ', 'Alleray - Procession)'],
#  ['75013 Paris 13e ', 'Salpétrière - Austerlitz)'],
#  ['75018 Paris 18e ', 'Barbès - Château Rouge)'],
#  ['75017 Paris 17e ', 'Ternes - Maillot)'],
#  ['75015 Paris 15e ', 'Alleray - Procession)'],
#  ['75020 Paris 20e ', 'Gambetta)'],
#  ['75006 Paris 6e ', 'Odéon - Mabillon)'],
#  ['75015 Paris 15e ', 'Citroën - Boucicaut)'],
#  ['75015 Paris 15e ', 'Dupleix - Motte Picquet)'],
#  ['75014 Paris 14e ', 'Montparnasse - Raspail)'],
#  ['75016 Paris 16e ', 'Auteuil-Nord - Jasmin - Mirabeau)'],
#  ['75009 Paris 9e ', 'Clichy - Trinité)'],
#  ['75017 Paris 17e ', 'Pereire)'],
#  ['75019 Paris 19e ', 'Danube)'],
#  ['75013 Paris 13e ', 'Olympiades - Choisy)'],
#  ['75013 Paris 13e ', 'Nationale - Deux Moulins)'],
#  ['75018 Paris 18e ', 'Montmartre - Sacré Coeur - Abbesses)'],
#  ['75016 Paris 16e'],
#  ['75015 Paris 15e'],
#  ['75017 Paris 17e'],
#  ['75015 Paris 15e'],
#  ['75012 Paris 12e']]

# %%
var1 = [x.split('(') for x in address]
PCQ = [] # Storing the adress into Postal Code, City and Quartier
compl = [] # Alocating the address complement to another variable

for i in range(0,len(var1)):
    a = var1[i] # temp. variable
    if len(a) > 1:
        b = a[0].strip() # temp. var. to store the first string containing postal code, city and quartier
        c = a[1].strip() # temp. var. to store the address complement
    else:
        b = a[0].strip()
        c = 'None'
        
    PCQ.append(b)
    compl.append(c)

# %%
# Removing the ')'
compl = [x.strip(')') for x in compl]

# %%
# Splitting PCQ into a list
PCQ = [x.split() for x in PCQ]
PCQ
# Out:
# [['75116', 'Paris', '16e'],
#  ['75015', 'Paris', '15e'],
#  ['75010', 'Paris', '10e'],
#  ['75017', 'Paris', '17e'],
#  ['75015', 'Paris', '15e'],
#  ['75020', 'Paris', '20e'],
#  ['75019', 'Paris', '19e'],
#  ['75019', 'Paris', '19e'],
#  ['75018', 'Paris', '18e'],
#  ['75002', 'Paris', '2e'],
#  ['75018', 'Paris', '18e'],
#  ['75014', 'Paris', '14e'],
#  ['75016', 'Paris', '16e'],
#  ['75007', 'Paris', '7e'],
#  ['75116', 'Paris', '16e'],
#  ['75004', 'Paris', '4e'],
#  ['75018', 'Paris', '18e'],
#  ['75018', 'Paris', '18e'],
#  ['75005', 'Paris', '5e'],
#  ['75017', 'Paris', '17e'],
#  ['75015', 'Paris', '15e'],
#  ['75019', 'Paris', '19e'],
#  ['75015', 'Paris', '15e'],
#  ['75018', 'Paris', '18e'],
#  ['75018', 'Paris', '18e'],
#  ['75116', 'Paris', '16e'],
#  ['75015', 'Paris', '15e'],
#  ['75116', 'Paris', '16e'],
#  ['75017', 'Paris', '17e'],
#  ['75020', 'Paris', '20e'],
#  ['75019', 'Paris', '19e'],
#  ['75014', 'Paris', '14e'],
#  ['75018', 'Paris', '18e'],
#  ['75007', 'Paris', '7e'],
#  ['75018', 'Paris', '18e'],
#  ['75017', 'Paris', '17e'],
#  ['75116', 'Paris', '16e'],
#  ['75020', 'Paris', '20e'],
#  ['75020', 'Paris', '20e'],
#  ['75019', 'Paris', '19e'],
#  ['75013', 'Paris', '13e'],
#  ['75015', 'Paris', '15e'],
#  ['75015', 'Paris', '15e'],
#  ['75018', 'Paris', '18e'],
#  ['75011', 'Paris', '11e'],
#  ['75010', 'Paris', '10e'],
#  ['75011', 'Paris', '11e'],
#  ['75019', 'Paris', '19e'],
#  ['75020', 'Paris', '20e'],
#  ['75017', 'Paris', '17e'],
#  ['75019', 'Paris', '19e'],
#  ['75009', 'Paris', '9e'],
#  ['75017', 'Paris', '17e'],
#  ['75015', 'Paris', '15e'],
#  ['75018', 'Paris', '18e'],
#  ['75014', 'Paris', '14e'],
#  ['75020', 'Paris', '20e'],
#  ['75018', 'Paris', '18e'],
#  ['75012', 'Paris', '12e'],
#  ['75018', 'Paris', '18e'],
#  ['75010', 'Paris', '10e'],
#  ['75015', 'Paris', '15e'],
#  ['75018', 'Paris', '18e'],
#  ['75014', 'Paris', '14e'],
#  ['75010', 'Paris', '10e'],
#  ['75015', 'Paris', '15e'],
#  ['75019', 'Paris', '19e'],
#  ['75019', 'Paris', '19e'],
#  ['75012', 'Paris', '12e'],
#  ['75020', 'Paris', '20e'],
#  ['75015', 'Paris', '15e'],
#  ['75012', 'Paris', '12e'],
#  ['75017', 'Paris', '17e'],
#  ['75018', 'Paris', '18e'],
#  ['75015', 'Paris', '15e'],
#  ['75015', 'Paris', '15e'],
#  ['75013', 'Paris', '13e'],
#  ['75018', 'Paris', '18e'],
#  ['75017', 'Paris', '17e'],
#  ['75015', 'Paris', '15e'],
#  ['75020', 'Paris', '20e'],
#  ['75006', 'Paris', '6e'],
#  ['75015', 'Paris', '15e'],
#  ['75015', 'Paris', '15e'],
#  ['75014', 'Paris', '14e'],
#  ['75016', 'Paris', '16e'],
#  ['75009', 'Paris', '9e'],
#  ['75017', 'Paris', '17e'],
#  ['75019', 'Paris', '19e'],
#  ['75013', 'Paris', '13e'],
#  ['75013', 'Paris', '13e'],
#  ['75018', 'Paris', '18e'],
#  ['75016', 'Paris', '16e'],
#  ['75015', 'Paris', '15e'],
#  ['75017', 'Paris', '17e'],
#  ['75015', 'Paris', '15e'],
#  ['75012', 'Paris', '12e']]

# %%
# Storing into another temp. DataFrame
t2 = pd.DataFrame(PCQ, columns= ['Postal Code','City','Quartier'])
t2
# Out:
#    Postal Code   City Quartier
# 0        75116  Paris      16e
# 1        75015  Paris      15e
# 2        75010  Paris      10e
# 3        75017  Paris      17e
# 4        75015  Paris      15e
# ..         ...    ...      ...
# 92       75016  Paris      16e
# 93       75015  Paris      15e
# 94       75017  Paris      17e
# 95       75015  Paris      15e
# 96       75012  Paris      12e
#
# [97 rows x 3 columns]

# %%
t2['Address'] = compl
t2
# Out:
#    Postal Code   City Quartier                  Address
# 0        75116  Paris      16e                 Dauphine
# 1        75015  Paris      15e     Alleray - Procession
# 2        75010  Paris      10e   Château d'Eau - Lancry
# 3        75017  Paris      17e    Champerret - Berthier
# 4        75015  Paris      15e  Dupleix - Motte Picquet
# ..         ...    ...      ...                      ...
# 92       75016  Paris      16e                     None
# 93       75015  Paris      15e                     None
# 94       75017  Paris      17e                     None
# 95       75015  Paris      15e                     None
# 96       75012  Paris      12e                     None
#
# [97 rows x 4 columns]

# %% [markdown]
#  ##### Adding everything to the final DataFrame

# %%
table = pd.concat([t1,t2],axis=1)
table
# Out:
#                Housing Surface Price Postal Code   City Quartier  \
# 0   Appartement meublé      11   750       75116  Paris      16e
# 1               Studio      28   950       75015  Paris      15e
# 2          Appartement      25   876       75010  Paris      10e
# 3   Appartement meublé      13   800       75017  Paris      17e
# 4          Appartement       9   340       75015  Paris      15e
# ..                 ...     ...   ...         ...    ...      ...
# 92         Appartement      15   840       75016  Paris      16e
# 93              Studio      20   870       75015  Paris      15e
# 94              Studio       9   530       75017  Paris      17e
# 95              Studio      22   900       75015  Paris      15e
# 96              Studio      20   850       75012  Paris      12e
#
#                     Address
# 0                  Dauphine
# 1      Alleray - Procession
# 2    Château d'Eau - Lancry
# 3     Champerret - Berthier
# 4   Dupleix - Motte Picquet
# ..                      ...
# 92                     None
# 93                     None
# 94                     None
# 95                     None
# 96                     None
#
# [97 rows x 7 columns]

# %% [markdown]
# # Apartment Link

# %% [markdown]
#  ##### Direct link to each ad

# %%
ap_link1 = soup1.find_all(['div','a'], {"class":"detailsContent adOverview"}) # tag
ap_link1 = [x.find('a').attrs['href'] for x in ap_link1] # text

# %%
ap_link2 = soup2.find_all(['div','a'], {"class":"detailsContent adOverview"})
ap_link2 = [x.find('a').attrs['href'] for x in ap_link2]

# %%
ap_link3 = soup3.find_all(['div','a'], {"class":"detailsContent adOverview"})
ap_link3 = [x.find('a').attrs['href'] for x in ap_link3]

# %%
ap_link4 = soup4.find_all(['div','a'], {"class":"detailsContent adOverview"})
ap_link4 = [x.find('a').attrs['href'] for x in ap_link4]

# %%
ap_link = []
ap_link.extend(ap_link1)
ap_link.extend(ap_link2)
ap_link.extend(ap_link3)
ap_link.extend(ap_link4)
len(ap_link)
# Out:
# 97

# %%
# Completing the link
link = []
for i in range(0,len(ap_link)):
    new = 'https://www.bienici.com' + ap_link[i]
    link.append(new)
    # print(link,'\n')

# %% [markdown]
# # FINAL TABLE

# %%
table['Link'] = link
table
# Out:
#                Housing Surface Price Postal Code   City Quartier  \
# 0   Appartement meublé      11   750       75116  Paris      16e
# 1               Studio      28   950       75015  Paris      15e
# 2          Appartement      25   876       75010  Paris      10e
# 3   Appartement meublé      13   800       75017  Paris      17e
# 4          Appartement       9   340       75015  Paris      15e
# ..                 ...     ...   ...         ...    ...      ...
# 92         Appartement      15   840       75016  Paris      16e
# 93              Studio      20   870       75015  Paris      15e
# 94              Studio       9   530       75017  Paris      17e
# 95              Studio      22   900       75015  Paris      15e
# 96              Studio      20   850       75012  Paris      12e
#
#                     Address                                               Link
# 0                  Dauphine  https://www.bienici.com/annonce/location/paris...
# 1      Alleray - Procession  https://www.bienici.com/annonce/location/paris...
# 2    Château d'Eau - Lancry  https://www.bienici.com/annonce/location/paris...
# 3     Champerret - Berthier  https://www.bienici.com/annonce/location/paris...
# 4   Dupleix - Motte Picquet  https://www.bienici.com/annonce/location/paris...
# ..                      ...                                                ...
# 92                     None  https://www.bienici.com/annonce/location/paris...
# 93                     None  https://www.bienici.com/annonce/location/paris...
# 94                     None  https://www.bienici.com/annonce/location/paris...
# 95                     None  https://www.bienici.com/annonce/location/paris...
# 96                     None  https://www.bienici.com/annonce/location/paris...
#
# [97 rows x 8 columns]

# %%
table.to_csv(r'C:\Users\Mateus de Alencar\Downloads\PortfolioProjects\Housing_Paris.csv', index = False, sep=';')
